# %%
import cv2

img = cv2.imread("my_img.jpeg")

# cv2.imshow("sjsds",img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
print(img)
# Out:
# [[[253 255 255]
#   [250 252 252]
#   [251 253 253]
#   ...
#   [255 255 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[253 255 255]
#   [250 252 252]
#   [252 254 254]
#   ...
#   [255 255 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [253 253 253]
#   [253 255 255]
#   ...
#   [255 255 254]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 251 250]
#   [255 255 254]
#   [255 255 254]
#   ...
#   [255 255 255]
#   [251 255 255]
#   [250 255 255]]
#
#  [[255 255 255]
#   [254 252 252]
#   [253 251 251]
#   ...
#   [253 255 255]
#   [251 255 255]
#   [250 255 255]]
#
#  [[251 255 255]
#   [248 252 253]
#   [251 255 255]
#   ...
#   [251 254 255]
#   [250 255 255]
#   [250 255 255]]]

# %%
img
# Out:
# array([[255, 252, 253, ..., 255, 255, 255],
#        [255, 252, 254, ..., 255, 255, 255],
#        [255, 253, 255, ..., 255, 255, 255],
#        ...,
#        [251, 255, 255, ..., 255, 255, 255],
#        [255, 252, 251, ..., 255, 255, 255],
#        [255, 252, 255, ..., 255, 255, 255]], shape=(223, 204), dtype=uint8)

# %%
cv2.imshow("sjsds",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
